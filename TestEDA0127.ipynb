# %% [markdown]
# <a href="https://colab.research.google.com/github/leejyy/Assignment/blob/master/TestEDA0127.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(style='whitegrid',palette='muted',font_scale=1.5)
plt.figsize=(16,10)

# %%
data=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/projects/test/test.csv')

# %%
data.head()
# Out:
#           Category        City         Country  ... Profit Quantity Sales
# 0  Office Supplies   Stockholm          Sweden  ...    -26        3    45
# 1        Furniture   Southport  United Kingdom  ...    290        7   854
# 2  Office Supplies     Valence          France  ...     21        3   140
# 3  Office Supplies  Birmingham  United Kingdom  ...    -22        2    27
# 4  Office Supplies  Birmingham  United Kingdom  ...     -1        2    17
#
# [5 rows x 18 columns]

# %%
data.describe
# Out:
# <bound method NDFrame.describe of              Category        City         Country  ... Profit Quantity Sales
# 0     Office Supplies   Stockholm          Sweden  ...    -26        3    45
# 1           Furniture   Southport  United Kingdom  ...    290        7   854
# 2     Office Supplies     Valence          France  ...     21        3   140
# 3     Office Supplies  Birmingham  United Kingdom  ...    -22        2    27
# 4     Office Supplies  Birmingham  United Kingdom  ...     -1        2    17
# ...               ...         ...             ...  ...    ...      ...   ...
# 8042        Furniture  Maidenhead  United Kingdom  ...     91        2   245
# 8043  Office Supplies   Eindhoven     Netherlands  ...    -10        2    30
# 8044  Office Supplies   Eindhoven     Netherlands  ...     -6        4    23
# 8045       Technology   Eindhoven     Netherlands  ...    -19        3   108
# 8046       Technology  Maidenhead  United Kingdom  ...    251        5   867
#
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of              Category        City         Country  ... Profit Quantity Sales
# 0     Office Supplies   Stockholm          Sweden  ...    -26        3    45
# 1           Furniture   Southport  United Kingdom  ...    290        7   854
# 2     Office Supplies     Valence          France  ...     21        3   140
# 3     Office Supplies  Birmingham  United Kingdom  ...    -22        2    27
# 4     Office Supplies  Birmingham  United Kingdom  ...     -1        2    17
# ...               ...         ...             ...  ...    ...      ...   ...
# 8042        Furniture  Maidenhead  United Kingdom  ...     91        2   245
# 8043  Office Supplies   Eindhoven     Netherlands  ...    -10        2    30
# 8044  Office Supplies   Eindhoven     Netherlands  ...     -6        4    23
# 8045       Technology   Eindhoven     Netherlands  ...    -19        3   108
# 8046       Technology  Maidenhead  United Kingdom  ...    251        5   867
#
# ...

# %% [markdown]
# ##Exploratory Data Analysis

# %%
data['Category'].hist(bins=10)
plt.xlabel('Category')
# Out:
# Text(0.5, 0, 'Category')

# %%
sns.jointplot(x='Country',y='Sales',data=data)

# %%
sns.jointplot(x='Category',y='Sales',data=data)

# %%
sns.countplot(x='Category',data=data,palette='bwr')

# %%
data['Country'].value_counts()
# Out:
# France            1916
# Germany           1640
# United Kingdom    1314
# Italy              979
# Spain              761
# Netherlands        393
# Austria            264
# Sweden             203
# Belgium            135
# Ireland            100
# Switzerland         78
# Norway              70
# Portugal            70
# Finland             64
# Denmark             60
# Name: Country, dtype: int64

# %%
sns.countplot(x='Country',data=data,palette="flare")
